# %% [markdown]
# ### Loading Images

# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread('./images/watch.jpg', cv2.IMREAD_GRAYSCALE)

# %%
image # получили массив со значениями насыщенности для каждого пиксела
# Out:
# array([[125, 123, 120, ..., 152, 152, 152],
#        [130, 127, 124, ..., 152, 152, 153],
#        [130, 127, 124, ..., 154, 154, 154],
#        ...,
#        [236, 238, 240, ..., 215, 215, 215],
#        [241, 237, 240, ..., 214, 214, 214],
#        [248, 240, 238, ..., 213, 213, 213]], dtype=uint8)

# %% [markdown]
# *Чем больше цветов -- тем больше данных, а это значит сложнее обрабатывать*
#
# Параметры ```cv2.imread()```:
#
# ```python
# cv2.IMREAD_COLOR #  (= 1) Loads a color image.
#                  # Any transparency of image will be neglected. It is the default flag.
# cv2.IMREAD_UNCHANGED # (= -1)
#                      # Loads image as such including alpha channel
# ```

# %%
plt.imshow(image, cmap='gray', interpolation='bicubic') # используем matplotlib и загружаем
plt.plot([50, 100], [80, 100], 'c', linewidth=5) # рисуем 1 линюю цвета 'cyan'
plt.show()

# %% [markdown]
# ### Loading Video Source

# %%
import cv2
import numpy as np

capture = cv2.VideoCapture(0);

# %%
while True:
    returning, frame = capture.read()
    cv2.imshow('frame', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'): # закрываем окошко камеры по нажатию 'q'
        break

capture.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### same but with writing video from the camera

# %%
import cv2
import numpy as np

capture = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('camera_output.avi', fourcc, 20.0, (640, 480))

while True:
    returning, frame = capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow('frame', frame)
    cv2.imshow('gray', gray)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

capture.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Drawing and Writing on Image
